# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Collecting numpy>=1.23.2
#   Downloading numpy-2.1.0-cp311-cp311-win_amd64.whl (12.9 MB)
#      ---------------------------------------- 12.9/12.9 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91626\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Requirement already satisfied: six>=1.5 in c:\users\91626\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.1.0 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp311-cp311-win_amd64.whl (7.8 MB)
#      ---------------------------------------- 7.8/7.8 MB 737.0 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
#      -------------------------------------- 188.2/188.2 kB 1.9 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.1-cp311-cp311-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 2.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in c:\users\91626\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\91626\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8
#   Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 2.2 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      -------------------------------------- 104.1/104.1 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91626\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\91626\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Data source:PetroWiki
#IPR data
q_ipr = [0,1999,3094,3902,4512,4963,5275,5458,5519]
pwf_ipr = [4000,3500,3000,2500,2000,1500,1000,500,14.7]
ipr = {'pwf':pwf_ipr,
      'Q':q_ipr}

# %%
ipr_df =pd.DataFrame({'pwf':pwf_ipr,
      'Q':q_ipr})
ipr_df
# Out:
#       pwf     Q
# 0  4000.0     0
# 1  3500.0  1999
# 2  3000.0  3094
# 3  2500.0  3902
# 4  2000.0  4512
# 5  1500.0  4963
# 6  1000.0  5275
# 7   500.0  5458
# 8    14.7  5519

# %%
x_ipr=q_ipr ;y_ipr=pwf_ipr
plt.figure(figsize=(8,4))
plt.plot(x_ipr,y_ipr)
plt.xlabel('Qoil(bbl/d)')
plt.ylabel('Pwf(psi)')
plt.title('IPR curve')
# Out:
# Text(0.5, 1.0, 'IPR curve')

# %%
#Data source:PetroWiki
#TPR data
q_tpr=[1000,1500,2000,2500,3000,3500,4000,4500,5000,5500,6000]
p_190=[1334,1400,1487,1592,1712,1843,1984,2132,2287,2446,2609]
p_2375=[1298,1320,1351,1390,1435,1487,1545,1609,1677,1749,1824]
p_2875=[1286,1294,1305,1319,1336,1356,1378,1403,1431,1461,1493]
tpr={'q':q_tpr,'Pwf(1.90"tbg)':p_190,'Pwf(2.375"tbg)':p_2375,'Pwf(2.875"tbg)':p_2875}

# %%
tpr_df = pd.DataFrame({'q':q_tpr,'Pwf(1.90"tbg)':p_190,'Pwf(2.375"tbg)':p_2375,'Pwf(2.875"tbg)':p_2875})
tpr_df
# Out:
#        q  Pwf(1.90"tbg)  Pwf(2.375"tbg)  Pwf(2.875"tbg)
# 0   1000           1334            1298            1286
# 1   1500           1400            1320            1294
# 2   2000           1487            1351            1305
# 3   2500           1592            1390            1319
# 4   3000           1712            1435            1336
# 5   3500           1843            1487            1356
# 6   4000           1984            1545            1378
# 7   4500           2132            1609            1403
# 8   5000           2287            1677            1431
# 9   5500           2446            1749            1461
# 10  6000           2609            1824            1493

# %%
plt.figure(figsize=(8,4))
plt.style.use('fivethirtyeight')
plt.plot(ipr['Q'],ipr['pwf'],label='IPR',linewidth=1.5)
plt.plot(tpr['q'],tpr['Pwf(1.90"tbg)'],label='TPR for 1.9" tubing',linewidth=1.5)
plt.plot(tpr['q'],tpr['Pwf(2.375"tbg)'],label='TPR for 2.375" tubing',linewidth=1.5)
plt.plot(tpr['q'],tpr['Pwf(2.875"tbg)'],label='TPR for 2.875" tubing',linewidth=1.5)
plt.xlabel('Flowrate(Mscf/D)')
plt.ylabel('Flowing BHP(Psia)')
plt.title('Nodal Analysis for a Gas Well')
plt.grid()
plt.legend(loc='best')
